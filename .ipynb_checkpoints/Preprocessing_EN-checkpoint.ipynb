# %%
import nltk
import spacy
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer

from nltk import pos_tag
from nltk.corpus import stopwords
import re
from nltk.corpus import wordnet
import pandas as pd

# import pyterrier as pt

# if not pt.started():
#     pt.init()

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("wordnet")
nltk.download("stopwords")

pd.set_option('display.max_colwidth',200)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import nltk
# ----> 2 import spacy
#       3 from nltk.tokenize import word_tokenize
#       4 from nltk.stem import WordNetLemmatizer
#
# ModuleNotFoundError: No module named 'spacy'

# %%
lawyers = pd.read_csv(r"Data\lawyers.csv").rename(columns={
    "id":"lawyer_id"
}).drop(columns={"email","email_verified_at","password","remember_token","phone","affiliation_date","created_at","updated_at"})
lawyers.head()
# Out:
#    lawyer_id      name            address union_branch union_number  \
# 0          1  Lawyer 1  1 Main St, City 1     Branch 2       UN0001
# 1          2  Lawyer 2  2 Main St, City 2     Branch 3       UN0002
# 2          3  Lawyer 3  3 Main St, City 3     Branch 1       UN0003
# 3          4  Lawyer 4  4 Main St, City 4     Branch 2       UN0004
# 4          5  Lawyer 5  5 Main St, City 5     Branch 3       UN0005
#
#    years_of_experience
# 0                    1
# 1                    4
# 2                   12
# 3                   13
# 4                   15

# %%
rates = pd.read_csv(r"Data\rates.csv").drop(columns={"created_at","updated_at","id"})
rates.head()
# Out:
#    lawyer_id  user_id  rating                                review
# 0        127     1558       2        Very professional and helpful.
# 1        141     1157       5       Not satisfied with the service.
# 2        148     1355       3        Very professional and helpful.
# 3        189     1050       4       Not satisfied with the service.
# 4        144     1658       1  Excellent service, highly recommend!

# %%
class Preprocessing_EN:
  @staticmethod
  def process(sentance):
    sentance = Preprocessing_EN.remove_punctuation(sentance)
    sentance = Preprocessing_EN.tokenizer(sentance)
    sentance = Preprocessing_EN.normalizer(sentance)
    sentance = Preprocessing_EN.remove_stopwords(sentance)
    sentance = Preprocessing_EN.remove_deplicate(sentance)
   
    sentance = Preprocessing_EN.lemmatizer2(sentance)
    # sentance = Preprocessing_EN.stemmer(sentance)
    
    return sentance

  @staticmethod
  def tokenizer(sentance):
    words = word_tokenize(sentance)
    return words

  @staticmethod
  def normalizer(sentance):
    return [word.lower() for word in sentance]

  @staticmethod
  def remove_stopwords(sentance):
    stop_words = set(stopwords.words('english'))
    sentance = [word for word in sentance if word not in stop_words]
    return sentance

  @staticmethod
  def lemmatizer1(sentance):
    lemmatize = WordNetLemmatizer()
    sentance = [lemmatize.lemmatize(word,pos="a") for word in sentance]
    return sentance
  
  
  @staticmethod
  def lemmatizer2(sentance):
    lemmatize =spacy.load("en_core_web_sm")
    sentance = [lemmatize.lemmatize(word,pos="a") for word in sentance]
    return sentance
  
  @staticmethod
  def stemmer(sentance):
    stemmer = PorterStemmer()
    sentance = [stemmer.stem(word) for word in sentance]
    return sentance

  @staticmethod
  def remove_punctuation(sentance):
    return re.sub(r'[^A-Za-z0-9\s]',' ',sentance)

  @staticmethod
  def remove_deplicate(sentance):
    return list(set(sentance))

# %%
text = """Artificial Intelligence (AI) is transforming industries across the globe. From healthcare to finance,
AI-powered solutions are making processes faster and more accurate. AI applications, such as natural
language processing and machine learning, are now mainstream in businesses, and their capabilities continue
to expand."""

text1 = """Rocks Making Swimming Saw Was watched see"""

Preprocessing_EN.process(text)
# Out:
# ['continu',
#  'healthcar',
#  'expand',
#  'fast',
#  'power',
#  'accur',
#  'artifici',
#  'machin',
#  'languag',
#  'mainstream',
#  'make',
#  'ai',
#  'financ',
#  'across',
#  'solut',
#  'capabl',
#  'natur',
#  'process',
#  'intellig',
#  'globe',
#  'learn',
#  'applic',
#  'busi',
#  'industri',
#  'process',
#  'transform']

# %%
lawyers_with_rates = lawyers.merge(rates,on="lawyer_id")

# %%
lawyers_with_rates['processed_text'] = lawyers_with_rates['review'].apply(Preprocessing_EN.process)
lawyers_with_rates.head()
# Out:
#    lawyer_id        name                address union_branch union_number  \
# 0        107  Lawyer 107  107 Main St, City 107     Branch 3       UN0107
# 1        110  Lawyer 110  110 Main St, City 110     Branch 3       UN0110
# 2        115  Lawyer 115  115 Main St, City 115     Branch 2       UN0115
# 3        121  Lawyer 121  121 Main St, City 121     Branch 2       UN0121
# 4        122  Lawyer 122  122 Main St, City 122     Branch 3       UN0122
#
#    years_of_experience  user_id  rating  \
# 0                    3     1351       1
# 1                    6     1358       5
# 2                   12     1515       3
# 3                   13     1724       4
# 4                   19     1957       4
#
#                                        review  \
# 0  Good, but communication could be improved.
# 1             Not satisfied with the service.
# 2  Good, but communication could be improved.
# 3        Excellent service, highly recommend!
# 4              Very professional and helpful.
#
#                        processed_text
# 0       [commun, good, could, improv]
# 1                   [satisfi, servic]
# 2       [commun, good, could, improv]
# 3  [highli, recommend, excel, servic]
# 4                  [profession, help]

# %%
lawyers_with_rates['text'] = lawyers_with_rates['address'].apply(Preprocessing_EN.process)
lawyers_with_rates.head()
# Out:
#    lawyer_id        name                address union_branch union_number  \
# 0        107  Lawyer 107  107 Main St, City 107     Branch 3       UN0107
# 1        110  Lawyer 110  110 Main St, City 110     Branch 3       UN0110
# 2        115  Lawyer 115  115 Main St, City 115     Branch 2       UN0115
# 3        121  Lawyer 121  121 Main St, City 121     Branch 2       UN0121
# 4        122  Lawyer 122  122 Main St, City 122     Branch 3       UN0122
#
#    years_of_experience  user_id  rating  \
# 0                    3     1351       1
# 1                    6     1358       5
# 2                   12     1515       3
# 3                   13     1724       4
# 4                   19     1957       4
#
#                                        review  \
# 0  Good, but communication could be improved.
# 1             Not satisfied with the service.
# 2  Good, but communication could be improved.
# 3        Excellent service, highly recommend!
# 4              Very professional and helpful.
#
#                        processed_text                   text
# 0       [commun, good, could, improv]  [main, citi, 107, st]
# 1                   [satisfi, servic]  [110, main, citi, st]
# 2       [commun, good, could, improv]  [main, 115, citi, st]
# 3  [highli, recommend, excel, servic]  [main, 121, citi, st]
# 4                  [profession, help]  [main, 122, citi, st]

# %%
columns_to_preprocess = ['address', 'union_branch','years_of_experience','rating','review']
for col in columns_to_preprocess:
    lawyers_with_rates['text'] = lawyers_with_rates[col].apply(Preprocessing_EN.process)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 columns_to_preprocess = ['address', 'union_branch','years_of_experience','rating','review']
#       2 for col in columns_to_preprocess:
# ----> 3     lawyers_with_rates['text'] = lawyers_with_rates[col].apply(Preprocessing_EN.process)
#
# File c:\Users\Mohammad Kher\Desktop\Projects\IR\venv\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\Mohammad Kher\Desktop\Projects\IR\venv\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\Mohammad Kher\Desktop\Projects\IR\venv\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\Mohammad Kher\Desktop\Projects\IR\venv\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\Mohammad Kher\Desktop\Projects\IR\venv\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[34], line 4, in Preprocessing_EN.process(sentance)
#       2 @staticmethod
#       3 def process(sentance):
# ----> 4   sentance = Preprocessing_EN.remove_punctuation(sentance)
#       5   sentance = Preprocessing_EN.tokenizer(sentance)
#       6   sentance = Preprocessing_EN.normalizer(sentance)
#
# Cell In[34], line 43, in Preprocessing_EN.remove_punctuation(sentance)
#      41 @staticmethod
#      42 def remove_punctuation(sentance):
# ---> 43   return re.sub(r'[^A-Za-z0-9\s]',' ',sentance)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:186, in sub(pattern, repl, string, count, flags)
#     179 def sub(pattern, repl, string, count=0, flags=0):
#     180     """Return the string obtained by replacing the leftmost
#     181     non-overlapping occurrences of the pattern in string by the
#     182     replacement repl.  repl can be either a string or a callable;
#     183     if a string, backslash escapes in it are processed.  If it is
#     184     a callable, it's passed the Match object and must return
#     185     a replacement string to be used."""
# --> 186     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object, got 'int'

# %%
lawyers_with_rates
# Out:
#     lawyer_id        name                address union_branch union_number  \
# 0         107  Lawyer 107  107 Main St, City 107     Branch 3       UN0107
# 1         110  Lawyer 110  110 Main St, City 110     Branch 3       UN0110
# 2         115  Lawyer 115  115 Main St, City 115     Branch 2       UN0115
# 3         121  Lawyer 121  121 Main St, City 121     Branch 2       UN0121
# 4         122  Lawyer 122  122 Main St, City 122     Branch 3       UN0122
# 5         127  Lawyer 127  127 Main St, City 127     Branch 2       UN0127
# 6         127  Lawyer 127  127 Main St, City 127     Branch 2       UN0127
# 7         134  Lawyer 134  134 Main St, City 134     Branch 3       UN0134
# 8         141  Lawyer 141  141 Main St, City 141     Branch 1       UN0141
# 9         144  Lawyer 144  144 Main St, City 144     Branch 1       UN0144
# 10        146  Lawyer 146  146 Main St, City 146     Branch 3       UN0146
# 11        148  Lawyer 148  148 Main St, City 148     Branch 2       UN0148
# 12        164  Lawyer 164  164 Main St, City 164     Branch 3       UN0164
# 13        169  Lawyer 169  169 Main St, City 169     Branch 2       UN0169
# 14        175  Lawyer 175  175 Main St, City 175     Branch 2       UN0175
# 15        180  Lawyer 180  180 Main St, City 180     Branch 1       UN0180
# 16        181  Lawyer 181  181 Main St, City 181     Branch 2       UN0181
# 17        189  Lawyer 189  189 Main St, City 189     Branch 1       UN0189
# 18        190  Lawyer 190  190 Main St, City 190     Branch 2       UN0190
# 19        197  Lawyer 197  197 Main St, City 197     Branch 3       UN0197
#
#     years_of_experience  user_id  rating  \
# 0                     3     1351       1
# 1                     6     1358       5
# 2                    12     1515       3
# 3                    13     1724       4
# 4                    19     1957       4
# 5                    11     1558       2
# 6                    11     1490       5
# 7                     1     1280       3
# 8                     1     1157       5
# 9                    14     1658       1
# 10                   14     1928       4
# 11                    5     1355       3
# 12                   19     1303       1
# 13                    1     1194       1
# 14                    2     1115       2
# 15                   15     1316       4
# 16                   15     1825       1
# 17                   13     1050       4
# 18                   14     1736       5
# 19                    9     1255       2
#
#                                         review  \
# 0   Good, but communication could be improved.
# 1              Not satisfied with the service.
# 2   Good, but communication could be improved.
# 3         Excellent service, highly recommend!
# 4               Very professional and helpful.
# 5               Very professional and helpful.
# 6   Good, but communication could be improved.
# 7   Good, but communication could be improved.
# 8              Not satisfied with the service.
# 9         Excellent service, highly recommend!
# 10   Exceptional experience, would hire again!
# 11              Very professional and helpful.
# 12        Excellent service, highly recommend!
# 13   Exceptional experience, would hire again!
# 14              Very professional and helpful.
# 15             Not satisfied with the service.
# 16              Very professional and helpful.
# 17             Not satisfied with the service.
# 18             Not satisfied with the service.
# 19  Good, but communication could be improved.
#
#                         processed_text         text
# 0        [commun, good, could, improv]  [3, branch]
# 1                    [satisfi, servic]  [3, branch]
# 2        [commun, good, could, improv]  [branch, 2]
# 3   [highli, recommend, excel, servic]  [branch, 2]
# 4                   [profession, help]  [3, branch]
# 5                   [profession, help]  [branch, 2]
# 6        [commun, good, could, improv]  [branch, 2]
# 7        [commun, good, could, improv]  [3, branch]
# 8                    [satisfi, servic]  [1, branch]
# 9   [highli, recommend, excel, servic]  [1, branch]
# 10       [hire, experi, except, would]  [3, branch]
# 11                  [profession, help]  [branch, 2]
# 12  [highli, recommend, excel, servic]  [3, branch]
# 13       [hire, experi, except, would]  [branch, 2]
# 14                  [profession, help]  [branch, 2]
# 15                   [satisfi, servic]  [1, branch]
# 16                  [profession, help]  [branch, 2]
# 17                   [satisfi, servic]  [1, branch]
# 18                   [satisfi, servic]  [branch, 2]
# 19       [commun, good, could, improv]  [3, branch]
